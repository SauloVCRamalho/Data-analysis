# %% [markdown]
# Object: This is a little project for show basic skills using data of companies that offer internet service in Rio de Janeiro-Brazil. It's used two companys to compare evolutions of tecnology and number contracts.

# %%
# First moment show SQL code used for extract data of database in "https://basedosdados.org/dataset/br-anatel-banda-larga-fixa?bdm_table=microdados"
#
#SELECT DISTINCT empresa AS company,
#ano AS year,
#mes AS month,
#tecnologia AS tecnology,
#velocidade AS speed_conection,
#acessos AS Number_contracts
#FROM `basedosdados.br_anatel_banda_larga_fixa.microdados` 
#WHERE empresa IN ('CLARO','TIM') AND sigla_uf='RJ'
#ORDER BY empresa, ano, mes, tecnologia, velocidade DESC
#

# %% [markdown]
# 1.   Import package.
# 2.   Import document that was prepared in Google Cloud using SQL.
# 3. Showing structure of data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('tim_claro_informations.csv')
complete_data=pd.DataFrame(df)
complete_data.head()
# Out:
#   company  year  month    tecnology   speed_conection  Number_contracts
# 0   CLARO  2007      3  Cable Modem  64Kbps a 512Kbps             49226
# 1   CLARO  2007      3  Cable Modem   512kbps a 2Mbps             76458
# 2   CLARO  2007      3  Cable Modem    2Mbps a 34Mbps             16807
# 3   CLARO  2007      3         FTTH          > 34Mbps                 5
# 4   CLARO  2007      3         FTTH          > 34Mbps                 1

# %% [markdown]
# Separate TIM and CLARO informations.

# %%
claro_table=complete_data.loc[complete_data['company']=='CLARO']
tim_table=complete_data.loc[complete_data['company']=='TIM']

# %%
claro_table.head(9)
# Out:
#   company  year  month    tecnology   speed_conection  Number_contracts
# 0   CLARO  2007      3  Cable Modem  64Kbps a 512Kbps             49226
# 1   CLARO  2007      3  Cable Modem   512kbps a 2Mbps             76458
# 2   CLARO  2007      3  Cable Modem    2Mbps a 34Mbps             16807
# 3   CLARO  2007      3         FTTH          > 34Mbps                 5
# 4   CLARO  2007      3         FTTH          > 34Mbps                 1
# 5   CLARO  2007      3         FTTH          > 34Mbps                 2
# 6   CLARO  2007      3         FTTH          > 34Mbps               130
# 7   CLARO  2007      3         FTTH  64Kbps a 512Kbps                 3
# 8   CLARO  2007      3         FTTH  64Kbps a 512Kbps                 2

# %%
tim_table.head()
# Out:
#       company  year  month tecnology  speed_conection  Number_contracts
# 40236     TIM  2007      3      FTTH  512kbps a 2Mbps               142
# 40237     TIM  2007      3       FWA  512kbps a 2Mbps                 2
# 40238     TIM  2007      3   Híbrido  512kbps a 2Mbps               265
# 40239     TIM  2007      3     Outra  512kbps a 2Mbps               182
# 40240     TIM  2007      3       SAT  512kbps a 2Mbps                 1

# %% [markdown]
# Claro Tecnology in time

# %%
modem_claro=claro_table.loc[claro_table['tecnology']=='Cable Modem']
FTTH_claro=claro_table.loc[claro_table['tecnology']=='FTTH']
FWA_claro=claro_table.loc[claro_table['tecnology']=='FWA']
hibrido_claro=claro_table.loc[claro_table['tecnology']=='Híbrido']
outra_claro=claro_table.loc[claro_table['tecnology']=='Outra']
wifi_claro=claro_table.loc[claro_table['tecnology']=='Wi-Fi']
xDSL_claro=claro_table.loc[claro_table['tecnology']=='xDSL']
fibra_claro=claro_table.loc[claro_table['tecnology']=='Fibra']
WIMAX_claro=claro_table.loc[claro_table['tecnology']=='WIMAX']
HFC_claro=claro_table.loc[claro_table['tecnology']=='HFC']
VSAT_claro=claro_table.loc[claro_table['tecnology']=='VSAT']
ADSL1_claro=claro_table.loc[claro_table['tecnology']=='ADSL1']
SAT_claro=claro_table.loc[claro_table['tecnology']=='SAT']

# %%
elementzero=[0]
claro_year2009modem=modem_claro.loc[modem_claro['year']==2009]
contracts_modem=[]
months_modem=[]
for i in list(sorted(set(claro_year2009modem['month'].tolist()))):
  claro_month_modem=claro_year2009modem.loc[claro_year2009modem['month']==i]
  claro_N_modem=sum(claro_month_modem['Number_contracts'].tolist())
  months_modem.append(i)
  contracts_modem.append(claro_N_modem)
listzero_modem=(12-len(months_modem))*elementzero
for i in range(0,len(contracts_modem),1):
  listzero_modem.insert(months_modem[i]-1,contracts_modem[i])
contracts_modem=listzero_modem

claro_year2009FTTH=FTTH_claro.loc[FTTH_claro['year']==2009]
contracts_FTTH=[]
months_FTTH=[]
for i in list(sorted(set(claro_year2009FTTH['month'].tolist()))):
  claro_month_FTTH=claro_year2009FTTH.loc[claro_year2009FTTH['month']==i]
  claro_N_FTTH=sum(claro_month_FTTH['Number_contracts'].tolist())
  months_FTTH.append(i)
  contracts_FTTH.append(claro_N_FTTH)
listzero_FTTH=(12-len(months_FTTH))*elementzero
for i in range(0,len(contracts_FTTH),1):
  listzero_FTTH.insert(months_FTTH[i]-1,contracts_FTTH[i])
contracts_FTTH=listzero_FTTH

claro_year2009FWA=FWA_claro.loc[FWA_claro['year']==2009]
contracts_FWA=[]
months_FWA=[]
for i in list(sorted(set(claro_year2009FWA['month'].tolist()))):
  claro_month_FWA=claro_year2009FWA.loc[claro_year2009FWA['month']==i]
  claro_N_FWA=sum(claro_month_FWA['Number_contracts'].tolist())
  months_FWA.append(i)
  contracts_FWA.append(claro_N_FWA)
listzero_FWA=(12-len(months_FWA))*elementzero
for i in range(0,len(contracts_FWA),1):
  listzero_FWA.insert(months_FWA[i]-1,contracts_FWA[i])
contracts_FWA=listzero_FWA

claro_year2009hibrido=hibrido_claro.loc[hibrido_claro['year']==2009]
contracts_hibrido=[]
months_hibrido=[]
for i in list(sorted(set(claro_year2009hibrido['month'].tolist()))):
  claro_month_hibrido=claro_year2009hibrido.loc[claro_year2009hibrido['month']==i]
  claro_N_hibrido=sum(claro_month_hibrido['Number_contracts'].tolist())
  months_hibrido.append(i)
  contracts_hibrido.append(claro_N_hibrido)
listzero_hibrido=(12-len(months_hibrido))*elementzero
for i in range(0,len(contracts_hibrido),1):
  listzero_hibrido.insert(months_hibrido[i]-1,contracts_hibrido[i])
contracts_hibrido=listzero_hibrido

claro_year2009wifi=wifi_claro.loc[wifi_claro['year']==2009]
contracts_wifi=[]
months_wifi=[]
for i in list(sorted(set(claro_year2009wifi['month'].tolist()))):
  claro_month_wifi=claro_year2009wifi.loc[claro_year2009wifi['month']==i]
  claro_N_wifi=sum(claro_month_wifi['Number_contracts'].tolist())
  months_wifi.append(i)
  contracts_wifi.append(claro_N_wifi)
listzero_wifi=(12-len(months_wifi))*elementzero
for i in range(0,len(contracts_wifi),1):
  listzero_wifi.insert(months_wifi[i]-1,contracts_wifi[i])
contracts_wifi=listzero_wifi

graph_2009 = pd.DataFrame({ 'Modem contracts (2009)': contracts_modem, 'FTTH contracts (2009)': contracts_FTTH ,
                           'FWA contracts (2009)': contracts_FWA, 'hibrid contracts (2009)': contracts_hibrido, 'Wi-Fi contracts (2009)': contracts_wifi}, index=range(1,13,1))
graph_2009.head(13)
# Out:
#     Modem contracts (2009)  FTTH contracts (2009)  FWA contracts (2009)  \
# 1                        0                      0                     0
# 2                        0                      0                     0
# 3                   271048                   3894                   500
# 4                        0                      0                     0
# 5                        0                      0                     0
# 6                   285893                   3520                   492
# 7                        0                      0                     0
# 8                        0                      0                     0
# 9                   301885                   3485                   490
# 10                       0                      0                     0
# 11                       0                      0                     0
# 12                  310954                   3319                   535
#
# ...

# %%
piegraph = pd.DataFrame({'contracts 2009': [sum(contracts_FTTH), sum(contracts_FWA),sum(contracts_hibrido),sum(contracts_wifi)]},
                  index=['FTTH', 'FWA','Hibrid','wi-fi'])
plot = piegraph.plot.pie(y='contracts 2009', figsize=(10, 10))

# %%
labels=range(1,13,1)
x = np.arange(len(labels))  # the label locations
width = 0.4  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, contracts_modem, width, label='contracts_Cable_modem')
rects2 = ax.bar(x + width/2, contracts_FTTH, width, label='contracts_FTTH')
rects3 = ax.bar(x - 3*width/2, contracts_FWA, width, label='contracts_FWA')
rects4 = ax.bar(x + 3*width/2, contracts_hibrido, width, label='contracts_hibrido')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number contracts')
ax.set_title('Number of contracts (2009)')
ax.set_xticks(x, 'labels')
ax.legend()

#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)
#ax.bar_label(rects3, padding=3)

fig.tight_layout()

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.

# %%
elementzero=[0]
###############################################################
#   Cable Modem tecnology
###############################################################
contract_by_year_modem=[]
years_modem=sorted(list(set(modem_claro['year'].tolist())))
for k in sorted(list(set(modem_claro['year'].tolist()))):
  claro_year_modem=modem_claro.loc[modem_claro['year']==k]
  contracts_modem=[]
  months_modem=[]
  for i in list(sorted(set(claro_year_modem['month'].tolist()))):
    claro_month_modem=claro_year_modem.loc[claro_year_modem['month']==i]
    claro_N_modem=sum(claro_month_modem['Number_contracts'].tolist())
    months_modem.append(i)
    contracts_modem.append(claro_N_modem)
  listzero_modem=(12-len(months_modem))*elementzero
  for i in range(0,len(contracts_modem),1):
    listzero_modem.insert(months_modem[i]-1,contracts_modem[i])
  contracts_modem=listzero_modem
  contract_by_year_modem.append(sum(contracts_modem))
####################################################################
listzero_modem_years=elementzero*(16-len(years_modem))
for i in range(0,len(contract_by_year_modem),1):
    listzero_modem_years.insert(years_modem[i]-2007,contract_by_year_modem[i])
contracts_modem_years=listzero_modem_years
###############################################################
#   FTTH tecnology
###############################################################
contract_by_year_FTTH=[]
years_FTTH=sorted(list(set(FTTH_claro['year'].tolist())))
for k in sorted(list(set(FTTH_claro['year'].tolist()))):
  claro_year_FTTH=FTTH_claro.loc[FTTH_claro['year']==k]
  contracts_FTTH=[]
  months_FTTH=[]
  for i in list(sorted(set(claro_year_FTTH['month'].tolist()))):
    claro_month_FTTH=claro_year_FTTH.loc[claro_year_FTTH['month']==i]
    claro_N_FTTH=sum(claro_month_FTTH['Number_contracts'].tolist())
    months_FTTH.append(i)
    contracts_FTTH.append(claro_N_FTTH)
  listzero_FTTH=(12-len(months_FTTH))*elementzero
  for i in range(0,len(contracts_FTTH),1):
    listzero_FTTH.insert(months_FTTH[i]-1,contracts_FTTH[i])
  contracts_FTTH=listzero_FTTH
  contract_by_year_FTTH.append(sum(contracts_FTTH))
###########################################################################
listzero_FTTH_years=elementzero*(16-len(years_FTTH))
for i in range(0,len(contract_by_year_FTTH),1):
    listzero_FTTH_years.insert(years_FTTH[i]-2007,contract_by_year_FTTH[i])
contracts_FTTH_years=listzero_FTTH_years
############################################################################
###############################################################
#   FWA tecnology
###############################################################
contract_by_year_FWA=[]
years_FWA=sorted(list(set(FWA_claro['year'].tolist())))
for k in sorted(list(set(FWA_claro['year'].tolist()))):
  claro_year_FWA=FWA_claro.loc[FWA_claro['year']==k]
  contracts_FWA=[]
  months_FWA=[]
  for i in list(sorted(set(claro_year_FWA['month'].tolist()))):
    claro_month_FWA=claro_year_FWA.loc[claro_year_FWA['month']==i]
    claro_N_FWA=sum(claro_month_FWA['Number_contracts'].tolist())
    months_FWA.append(i)
    contracts_FWA.append(claro_N_FWA)
  listzero_FWA=(12-len(months_FWA))*elementzero
  for i in range(0,len(contracts_FWA),1):
    listzero_FWA.insert(months_FWA[i]-1,contracts_FWA[i])
  contracts_FWA=listzero_FWA
  contract_by_year_FWA.append(sum(contracts_FWA))
###########################################################################
listzero_FWA_years=elementzero*(16-len(years_FWA))
for i in range(0,len(contract_by_year_FWA),1):
    listzero_FWA_years.insert(years_FWA[i]-2007,contract_by_year_FWA[i])
contracts_FWA_years=listzero_FWA_years
############################################################################
#   SAT tecnology
###############################################################
contract_by_year_SAT=[]
years_SAT=sorted(list(set(SAT_claro['year'].tolist())))
for k in sorted(list(set(SAT_claro['year'].tolist()))):
  claro_year_SAT=SAT_claro.loc[SAT_claro['year']==k]
  contracts_SAT=[]
  months_SAT=[]
  for i in list(sorted(set(claro_year_SAT['month'].tolist()))):
    claro_month_SAT=claro_year_SAT.loc[claro_year_SAT['month']==i]
    claro_N_SAT=sum(claro_month_SAT['Number_contracts'].tolist())
    months_SAT.append(i)
    contracts_SAT.append(claro_N_SAT)
  listzero_SAT=(12-len(months_SAT))*elementzero
  for i in range(0,len(contracts_SAT),1):
    listzero_SAT.insert(months_SAT[i]-1,contracts_SAT[i])
  contracts_SAT=listzero_SAT
  contract_by_year_SAT.append(sum(contracts_SAT))
###########################################################################
listzero_SAT_years=elementzero*(16-len(years_SAT))
for i in range(0,len(contract_by_year_SAT),1):
    listzero_SAT_years.insert(years_SAT[i]-2007,contract_by_year_SAT[i])
contracts_SAT_years=listzero_SAT_years
############################################################################
#   XDSL tecnology
###############################################################
contract_by_year_xDSL=[]
years_xDSL=sorted(list(set(xDSL_claro['year'].tolist())))
for k in sorted(list(set(xDSL_claro['year'].tolist()))):
  claro_year_xDSL=xDSL_claro.loc[xDSL_claro['year']==k]
  contracts_xDSL=[]
  months_xDSL=[]
  for i in list(sorted(set(claro_year_xDSL['month'].tolist()))):
    claro_month_xDSL=claro_year_xDSL.loc[claro_year_xDSL['month']==i]
    claro_N_xDSL=sum(claro_month_xDSL['Number_contracts'].tolist())
    months_xDSL.append(i)
    contracts_xDSL.append(claro_N_xDSL)
  listzero_xDSL=(12-len(months_xDSL))*elementzero
  for i in range(0,len(contracts_xDSL),1):
    listzero_xDSL.insert(months_xDSL[i]-1,contracts_xDSL[i])
  contracts_xDSL=listzero_xDSL
  contract_by_year_xDSL.append(sum(contracts_xDSL))
###########################################################################
listzero_xDSL_years=elementzero*(16-len(years_xDSL))
for i in range(0,len(contract_by_year_xDSL),1):
    listzero_xDSL_years.insert(years_xDSL[i]-2007,contract_by_year_xDSL[i])
contracts_xDSL_years=listzero_xDSL_years
############################################################################
############################################################################
#   VSAT tecnology
###############################################################
contract_by_year_VSAT=[]
years_VSAT=sorted(list(set(VSAT_claro['year'].tolist())))
for k in sorted(list(set(VSAT_claro['year'].tolist()))):
  claro_year_VSAT=VSAT_claro.loc[VSAT_claro['year']==k]
  contracts_VSAT=[]
  months_VSAT=[]
  for i in list(sorted(set(claro_year_VSAT['month'].tolist()))):
    claro_month_VSAT=claro_year_VSAT.loc[claro_year_VSAT['month']==i]
    claro_N_VSAT=sum(claro_month_VSAT['Number_contracts'].tolist())
    months_VSAT.append(i)
    contracts_VSAT.append(claro_N_VSAT)
  listzero_VSAT=(12-len(months_VSAT))*elementzero
  for i in range(0,len(contracts_VSAT),1):
    listzero_VSAT.insert(months_VSAT[i]-1,contracts_VSAT[i])
  contracts_VSAT=listzero_VSAT
  contract_by_year_VSAT.append(sum(contracts_VSAT))
###########################################################################
listzero_VSAT_years=elementzero*(16-len(years_VSAT))
for i in range(0,len(contract_by_year_VSAT),1):
    listzero_VSAT_years.insert(years_VSAT[i]-2007,contract_by_year_VSAT[i])
contracts_VSAT_years=listzero_VSAT_years
############################################################################
#   HFC tecnology
###############################################################
contract_by_year_HFC=[]
years_HFC=sorted(list(set(HFC_claro['year'].tolist())))
for k in sorted(list(set(HFC_claro['year'].tolist()))):
  claro_year_HFC=HFC_claro.loc[HFC_claro['year']==k]
  contracts_HFC=[]
  months_HFC=[]
  for i in list(sorted(set(claro_year_HFC['month'].tolist()))):
    claro_month_HFC=claro_year_HFC.loc[claro_year_HFC['month']==i]
    claro_N_HFC=sum(claro_month_HFC['Number_contracts'].tolist())
    months_HFC.append(i)
    contracts_HFC.append(claro_N_HFC)
  listzero_HFC=(12-len(months_HFC))*elementzero
  for i in range(0,len(contracts_HFC),1):
    listzero_HFC.insert(months_HFC[i]-1,contracts_HFC[i])
  contracts_HFC=listzero_HFC
  contract_by_year_HFC.append(sum(contracts_HFC))
###########################################################################
listzero_HFC_years=elementzero*(16-len(years_HFC))
for i in range(0,len(contract_by_year_HFC),1):
    listzero_HFC_years.insert(years_HFC[i]-2007,contract_by_year_HFC[i])
contracts_HFC_years=listzero_HFC_years
############################################################################
#   WIMAX tecnology
###############################################################
contract_by_year_WIMAX=[]
years_WIMAX=sorted(list(set(WIMAX_claro['year'].tolist())))
for k in sorted(list(set(WIMAX_claro['year'].tolist()))):
  claro_year_WIMAX=WIMAX_claro.loc[WIMAX_claro['year']==k]
  contracts_WIMAX=[]
  months_WIMAX=[]
  for i in list(sorted(set(claro_year_WIMAX['month'].tolist()))):
    claro_month_WIMAX=claro_year_WIMAX.loc[claro_year_WIMAX['month']==i]
    claro_N_WIMAX=sum(claro_month_WIMAX['Number_contracts'].tolist())
    months_WIMAX.append(i)
    contracts_WIMAX.append(claro_N_WIMAX)
  listzero_WIMAX=(12-len(months_WIMAX))*elementzero
  for i in range(0,len(contracts_WIMAX),1):
    listzero_WIMAX.insert(months_WIMAX[i]-1,contracts_WIMAX[i])
  contracts_WIMAX=listzero_WIMAX
  contract_by_year_WIMAX.append(sum(contracts_WIMAX))
###########################################################################
listzero_WIMAX_years=elementzero*(16-len(years_WIMAX))
for i in range(0,len(contract_by_year_WIMAX),1):
    listzero_WIMAX_years.insert(years_WIMAX[i]-2007,contract_by_year_WIMAX[i])
contracts_WIMAX_years=listzero_WIMAX_years
############################################################################
############################################################################
#   wi-fi tecnology
###############################################################
contract_by_year_wifi=[]
years_wifi=sorted(list(set(wifi_claro['year'].tolist())))
for k in sorted(list(set(wifi_claro['year'].tolist()))):
  claro_year_wifi=wifi_claro.loc[wifi_claro['year']==k]
  contracts_wifi=[]
  months_wifi=[]
  for i in list(sorted(set(claro_year_wifi['month'].tolist()))):
    claro_month_wifi=claro_year_wifi.loc[claro_year_wifi['month']==i]
    claro_N_wifi=sum(claro_month_wifi['Number_contracts'].tolist())
    months_wifi.append(i)
    contracts_wifi.append(claro_N_wifi)
  listzero_wifi=(12-len(months_wifi))*elementzero
  for i in range(0,len(contracts_wifi),1):
    listzero_wifi.insert(months_wifi[i]-1,contracts_wifi[i])
  contracts_wifi=listzero_wifi
  contract_by_year_wifi.append(sum(contracts_wifi))
###########################################################################
listzero_wifi_years=elementzero*(16-len(years_wifi))
for i in range(0,len(contract_by_year_wifi),1):
    listzero_wifi_years.insert(years_wifi[i]-2007,contract_by_year_wifi[i])
contracts_wifi_years=listzero_wifi_years
############################################################################
############################################################################
#   ADSL1 tecnology
###############################################################
contract_by_year_ADSL1=[]
years_ADSL1=sorted(list(set(ADSL1_claro['year'].tolist())))
for k in sorted(list(set(ADSL1_claro['year'].tolist()))):
  claro_year_ADSL1=ADSL1_claro.loc[ADSL1_claro['year']==k]
  contracts_ADSL1=[]
  months_ADSL1=[]
  for i in list(sorted(set(claro_year_ADSL1['month'].tolist()))):
    claro_month_ADSL1=claro_year_ADSL1.loc[claro_year_ADSL1['month']==i]
    claro_N_ADSL1=sum(claro_month_ADSL1['Number_contracts'].tolist())
    months_ADSL1.append(i)
    contracts_ADSL1.append(claro_N_ADSL1)
  listzero_ADSL1=(12-len(months_ADSL1))*elementzero
  for i in range(0,len(contracts_ADSL1),1):
    listzero_ADSL1.insert(months_ADSL1[i]-1,contracts_ADSL1[i])
  contracts_ADSL1=listzero_ADSL1
  contract_by_year_ADSL1.append(sum(contracts_ADSL1))
###########################################################################
listzero_ADSL1_years=elementzero*(16-len(years_ADSL1))
for i in range(0,len(contract_by_year_ADSL1),1):
    listzero_ADSL1_years.insert(years_ADSL1[i]-2007,contract_by_year_ADSL1[i])
contracts_ADSL1_years=listzero_ADSL1_years
############################################################################
############################################################################
#   Fiber tecnology
###############################################################
contract_by_year_fibra=[]
years_fibra=sorted(list(set(fibra_claro['year'].tolist())))
for k in sorted(list(set(fibra_claro['year'].tolist()))):
  claro_year_fibra=fibra_claro.loc[fibra_claro['year']==k]
  contracts_fibra=[]
  months_fibra=[]
  for i in list(sorted(set(claro_year_fibra['month'].tolist()))):
    claro_month_fibra=claro_year_fibra.loc[claro_year_fibra['month']==i]
    claro_N_fibra=sum(claro_month_fibra['Number_contracts'].tolist())
    months_fibra.append(i)
    contracts_fibra.append(claro_N_fibra)
  listzero_fibra=(12-len(months_fibra))*elementzero
  for i in range(0,len(contracts_fibra),1):
    listzero_fibra.insert(months_fibra[i]-1,contracts_fibra[i])
  contracts_fibra=listzero_fibra
  contract_by_year_fibra.append(sum(contracts_fibra))
###########################################################################
listzero_fibra_years=elementzero*(16-len(years_fibra))
for i in range(0,len(contract_by_year_fibra),1):
    listzero_fibra_years.insert(years_fibra[i]-2007,contract_by_year_fibra[i])
contracts_fibra_years=listzero_fibra_years
############################################################################
############################################################################
#   hibrid tecnology
###############################################################
contract_by_year_hibrido=[]
years_hibrido=sorted(list(set(hibrido_claro['year'].tolist())))
for k in sorted(list(set(hibrido_claro['year'].tolist()))):
  claro_year_hibrido=hibrido_claro.loc[hibrido_claro['year']==k]
  contracts_hibrido=[]
  months_hibrido=[]
  for i in list(sorted(set(claro_year_hibrido['month'].tolist()))):
    claro_month_hibrido=claro_year_hibrido.loc[claro_year_hibrido['month']==i]
    claro_N_hibrido=sum(claro_month_hibrido['Number_contracts'].tolist())
    months_hibrido.append(i)
    contracts_hibrido.append(claro_N_hibrido)
  listzero_hibrido=(12-len(months_hibrido))*elementzero
  for i in range(0,len(contracts_hibrido),1):
    listzero_hibrido.insert(months_hibrido[i]-1,contracts_hibrido[i])
  contracts_hibrido=listzero_hibrido
  contract_by_year_hibrido.append(sum(contracts_hibrido))
###########################################################################
listzero_hibrido_years=elementzero*(16-len(years_hibrido))
for i in range(0,len(contract_by_year_hibrido),1):
    listzero_hibrido_years.insert(years_hibrido[i]-2007,contract_by_year_hibrido[i])
contracts_hibrido_years=listzero_hibrido_years
############################################################################
############################################################################
#   other tecnologies
###############################################################
contract_by_year_outra=[]
years_outra=sorted(list(set(outra_claro['year'].tolist())))
for k in sorted(list(set(outra_claro['year'].tolist()))):
  claro_year_outra=outra_claro.loc[outra_claro['year']==k]
  contracts_outra=[]
  months_outra=[]
  for i in list(sorted(set(claro_year_outra['month'].tolist()))):
    claro_month_outra=claro_year_outra.loc[claro_year_outra['month']==i]
    claro_N_outra=sum(claro_month_outra['Number_contracts'].tolist())
    months_outra.append(i)
    contracts_outra.append(claro_N_outra)
  listzero_outra=(12-len(months_outra))*elementzero
  for i in range(0,len(contracts_outra),1):
    listzero_outra.insert(months_outra[i]-1,contracts_outra[i])
  contracts_outra=listzero_outra
  contract_by_year_outra.append(sum(contracts_outra))
###########################################################################
listzero_outra_years=elementzero*(16-len(years_outra))
for i in range(0,len(contract_by_year_outra),1):
    listzero_outra_years.insert(years_outra[i]-2007,contract_by_year_outra[i])
contracts_outra_years=listzero_outra_years
############################################################################

# %%
time_all=[2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]

piegraph_claro_2007_2008 = pd.DataFrame({'contracts 2007': [sum([contracts_outra_years[0],contracts_hibrido_years[0], contracts_fibra_years[0],contracts_ADSL1_years[0],
                                            contracts_wifi_years[0], contracts_WIMAX_years[0], contracts_HFC_years[0],contracts_VSAT_years[0],
                                            contracts_xDSL_years[0],contracts_SAT_years[0],contracts_FWA_years[0],contracts_FTTH_years[0]]),contracts_modem_years[0]],
                               'contracts 2008':[sum([contracts_outra_years[1],contracts_hibrido_years[1], contracts_fibra_years[1],contracts_ADSL1_years[1],
                                            contracts_wifi_years[1], contracts_WIMAX_years[1], contracts_HFC_years[1],contracts_VSAT_years[1],
                                            contracts_xDSL_years[1],contracts_SAT_years[1],contracts_FWA_years[1],contracts_FTTH_years[1]]),contracts_modem_years[1]]},
                  index=['Other services', 'Modem'])
#plot = piegraph_claro_2007_2008.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2007_2008.plot.pie(subplots=True, figsize=(20, 20))

# %% [markdown]
# Analysis of other internet services (without cable modem)

# %%
piegraph_claro_2007_2008out = pd.DataFrame({'contracts 2007(without Modem) ': [contracts_outra_years[0],contracts_hibrido_years[0], contracts_fibra_years[0],contracts_ADSL1_years[0],
                                            contracts_wifi_years[0], contracts_WIMAX_years[0], contracts_HFC_years[0],contracts_VSAT_years[0],
                                            contracts_xDSL_years[0],contracts_SAT_years[0],contracts_FWA_years[0],contracts_FTTH_years[0]],
                               'contracts 2008(without Modem)':[contracts_outra_years[1],contracts_hibrido_years[1], contracts_fibra_years[1],contracts_ADSL1_years[1],
                                            contracts_wifi_years[1], contracts_WIMAX_years[1], contracts_HFC_years[1],contracts_VSAT_years[1],
                                            contracts_xDSL_years[1],contracts_SAT_years[1],contracts_FWA_years[1],contracts_FTTH_years[1]]},
                  index=['Others','Hibrid','Fiber','ADSL1','Wi-Fi','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH'])
#plot = piegraph_claro_2007_2008out.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2007_2008out.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2009_2010 = pd.DataFrame({'contracts 2009':[sum([contracts_outra_years[2],contracts_hibrido_years[2], contracts_fibra_years[2],contracts_ADSL1_years[2],
                                            contracts_wifi_years[2], contracts_WIMAX_years[2], contracts_HFC_years[2],contracts_VSAT_years[2],
                                            contracts_xDSL_years[2],contracts_SAT_years[2],contracts_FWA_years[2],contracts_FTTH_years[2]]),contracts_modem_years[2]],
                               'contracts 2010':[sum([contracts_outra_years[3],contracts_hibrido_years[3], contracts_fibra_years[3],contracts_ADSL1_years[3],
                                            contracts_wifi_years[3], contracts_WIMAX_years[3], contracts_HFC_years[3],contracts_VSAT_years[3],
                                            contracts_xDSL_years[3],contracts_SAT_years[3],contracts_FWA_years[3],contracts_FTTH_years[3]]),contracts_modem_years[3]]},
                  index=['Other tecnologies', 'Modem'])
#plot = piegraph_claro_2009_2010.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2009_2010.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2009_2010out = pd.DataFrame({'contracts 2009(without Modem)':[contracts_outra_years[2],contracts_hibrido_years[2], contracts_fibra_years[2],contracts_ADSL1_years[2],
                                            contracts_wifi_years[2], contracts_WIMAX_years[2], contracts_HFC_years[2],contracts_VSAT_years[2],
                                            contracts_xDSL_years[2],contracts_SAT_years[2],contracts_FWA_years[2],contracts_FTTH_years[2]],
                               'contracts 2010 (without Modem)':[contracts_outra_years[3],contracts_hibrido_years[3], contracts_fibra_years[3],contracts_ADSL1_years[3],
                                            contracts_wifi_years[3], contracts_WIMAX_years[3], contracts_HFC_years[3],contracts_VSAT_years[3],
                                            contracts_xDSL_years[3],contracts_SAT_years[3],contracts_FWA_years[3],contracts_FTTH_years[3]]},
                  index=['Others','Hibrid','Fiber','ADSL1','Wi-Fi','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH'])
#plot = piegraph_claro_2009_2010.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2009_2010out.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2011_2012 = pd.DataFrame({'contracts 2011':[sum([contracts_outra_years[4],contracts_hibrido_years[4], contracts_fibra_years[4],contracts_ADSL1_years[4],
                                            contracts_wifi_years[4], contracts_WIMAX_years[4], contracts_HFC_years[4],contracts_VSAT_years[4],
                                            contracts_xDSL_years[4],contracts_SAT_years[4],contracts_FWA_years[4],contracts_FTTH_years[4]]),contracts_modem_years[4]], 
                                         'contracts 2012':[sum([contracts_outra_years[5],contracts_hibrido_years[5], contracts_fibra_years[5],contracts_ADSL1_years[5],
                                            contracts_wifi_years[5], contracts_WIMAX_years[5], contracts_HFC_years[5],contracts_VSAT_years[5],
                                            contracts_xDSL_years[5],contracts_SAT_years[5],contracts_FWA_years[5],contracts_FTTH_years[5]]),contracts_modem_years[5]] },
                  index=['Other tecnologies', 'Modem'])
#plot = piegraph_claro_2009_2010.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2011_2012.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2011_2012out = pd.DataFrame({'contracts 2011 (without Modem)':[contracts_outra_years[4],contracts_hibrido_years[4], contracts_fibra_years[4],contracts_ADSL1_years[4],
                                            contracts_wifi_years[4], contracts_WIMAX_years[4], contracts_HFC_years[4],contracts_VSAT_years[4],
                                            contracts_xDSL_years[4],contracts_SAT_years[4],contracts_FWA_years[4],contracts_FTTH_years[4]], 
                                         'contracts 2012 (Without Modem)':[contracts_outra_years[5],contracts_hibrido_years[5], contracts_fibra_years[5],contracts_ADSL1_years[5],
                                            contracts_wifi_years[5], contracts_WIMAX_years[5], contracts_HFC_years[5],contracts_VSAT_years[5],
                                            contracts_xDSL_years[5],contracts_SAT_years[5],contracts_FWA_years[5],contracts_FTTH_years[5]]},
                  index=['Others','Hibrid','Fiber','ADSL1','Wi-Fi','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH'])
#plot = piegraph_claro_2009_2010.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2011_2012out.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2013_2014 = pd.DataFrame({'contracts 2013':[sum([contracts_outra_years[6],contracts_hibrido_years[6], contracts_fibra_years[6],contracts_ADSL1_years[6],
                                            contracts_wifi_years[6], contracts_WIMAX_years[6], contracts_HFC_years[6],contracts_VSAT_years[6],
                                            contracts_xDSL_years[6],contracts_SAT_years[6],contracts_FWA_years[6],contracts_FTTH_years[6]]),contracts_modem_years[6]], 
                                         'contracts 2014':[sum([contracts_outra_years[7],contracts_hibrido_years[7], contracts_fibra_years[7],contracts_ADSL1_years[7],
                                            contracts_wifi_years[7], contracts_WIMAX_years[7], contracts_HFC_years[7],contracts_VSAT_years[7],
                                            contracts_xDSL_years[7],contracts_SAT_years[7],contracts_FWA_years[7],contracts_FTTH_years[7]]),contracts_modem_years[7]] },
                  index=['Other tecnologies', 'Modem'])
#plot = piegraph_claro_2013_2014.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2013_2014.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2013_2014out = pd.DataFrame({'contracts 2013 (Without Modem)':[contracts_outra_years[6],contracts_hibrido_years[6], contracts_fibra_years[6],contracts_ADSL1_years[6],
                                            contracts_wifi_years[6], contracts_WIMAX_years[6], contracts_HFC_years[6],contracts_VSAT_years[6],
                                            contracts_xDSL_years[6],contracts_SAT_years[6],contracts_FWA_years[6],contracts_FTTH_years[6]], 
                                         'contracts 2014 (Without Modem)':[contracts_outra_years[7],contracts_hibrido_years[7], contracts_fibra_years[7],contracts_ADSL1_years[7],
                                            contracts_wifi_years[7], contracts_WIMAX_years[7], contracts_HFC_years[7],contracts_VSAT_years[7],
                                            contracts_xDSL_years[7],contracts_SAT_years[7],contracts_FWA_years[7],contracts_FTTH_years[7]] },
                  index=['Others','Hibrid','Fiber','ADSL1','Wi-Fi','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH'])
#plot = piegraph_claro_2013_2014.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2013_2014out.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2015_2016 = pd.DataFrame({'contracts 2015':[sum([contracts_outra_years[8],contracts_hibrido_years[8], contracts_fibra_years[8],contracts_ADSL1_years[8],
                                            contracts_wifi_years[8], contracts_WIMAX_years[8], contracts_HFC_years[8],contracts_VSAT_years[8],
                                            contracts_xDSL_years[8],contracts_SAT_years[8],contracts_FWA_years[8],contracts_FTTH_years[8]]),contracts_modem_years[8]], 
                                         'contracts 2016':[sum([contracts_outra_years[9],contracts_hibrido_years[9], contracts_fibra_years[9],contracts_ADSL1_years[9],
                                            contracts_wifi_years[9], contracts_WIMAX_years[9], contracts_HFC_years[9],contracts_VSAT_years[9],
                                            contracts_xDSL_years[9],contracts_SAT_years[9],contracts_FWA_years[9],contracts_FTTH_years[9]]),contracts_modem_years[9]] },
                  index=['Other tecnologies', 'Modem'])
#plot = piegraph_claro_2015_2016.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2015_2016.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2015_2016out = pd.DataFrame({'contracts 2015 (Without Modem)':[contracts_outra_years[8],contracts_hibrido_years[8], contracts_fibra_years[8],contracts_ADSL1_years[8],
                                            contracts_wifi_years[8], contracts_WIMAX_years[8], contracts_HFC_years[8],contracts_VSAT_years[8],
                                            contracts_xDSL_years[8],contracts_SAT_years[8],contracts_FWA_years[8],contracts_FTTH_years[8]], 
                                         'contracts 2016 (Without Modem)':[contracts_outra_years[9],contracts_hibrido_years[9], contracts_fibra_years[9],contracts_ADSL1_years[9],
                                            contracts_wifi_years[9], contracts_WIMAX_years[9], contracts_HFC_years[9],contracts_VSAT_years[9],
                                            contracts_xDSL_years[9],contracts_SAT_years[9],contracts_FWA_years[9],contracts_FTTH_years[9]] },
                  index=['Others','Hibrid','Fiber','ADSL1','Wi-Fi','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH'])
#plot = piegraph_claro_2015_2016.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2015_2016out.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2017_2018 = pd.DataFrame({'contracts 2017':[sum([contracts_outra_years[10],contracts_hibrido_years[10], contracts_fibra_years[10],contracts_ADSL1_years[10],
                                            contracts_wifi_years[10], contracts_WIMAX_years[10], contracts_HFC_years[10],contracts_VSAT_years[10],
                                            contracts_xDSL_years[10],contracts_SAT_years[10],contracts_FWA_years[10],contracts_FTTH_years[10]]),contracts_modem_years[10]], 
                                         'contracts 2018':[sum([contracts_outra_years[11],contracts_hibrido_years[11], contracts_fibra_years[11],contracts_ADSL1_years[11],
                                            contracts_wifi_years[11], contracts_WIMAX_years[11], contracts_HFC_years[11],contracts_VSAT_years[11],
                                            contracts_xDSL_years[11],contracts_SAT_years[11],contracts_FWA_years[11],contracts_FTTH_years[11]]),contracts_modem_years[11]] },
                  index=['Other tecnologies', 'Modem'])
#plot = piegraph_claro_2017_2018.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2017_2018.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2017_2018out = pd.DataFrame({'contracts 2017 (without Modem)':[contracts_outra_years[10],contracts_hibrido_years[10], contracts_fibra_years[10],contracts_ADSL1_years[10],
                                            contracts_wifi_years[10], contracts_WIMAX_years[10], contracts_HFC_years[10],contracts_VSAT_years[10],
                                            contracts_xDSL_years[10],contracts_SAT_years[10],contracts_FWA_years[10],contracts_FTTH_years[10]], 
                                         'contracts 2018 (without Modem)':[contracts_outra_years[11],contracts_hibrido_years[11], contracts_fibra_years[11],contracts_ADSL1_years[11],
                                            contracts_wifi_years[11], contracts_WIMAX_years[11], contracts_HFC_years[11],contracts_VSAT_years[11],
                                            contracts_xDSL_years[11],contracts_SAT_years[11],contracts_FWA_years[11],contracts_FTTH_years[11]] },
                  index=['Others','Hibrid','Fiber','ADSL1','Wi-Fi','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH'])
#plot = piegraph_claro_2017_2018.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2017_2018out.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2019_2020 = pd.DataFrame({'contracts 2019':[sum([contracts_outra_years[12],contracts_hibrido_years[12], contracts_fibra_years[12],contracts_ADSL1_years[12],
                                            contracts_wifi_years[12], contracts_WIMAX_years[12],contracts_VSAT_years[12],
                                            contracts_xDSL_years[12],contracts_SAT_years[12],contracts_FWA_years[12],contracts_FTTH_years[12],contracts_modem_years[12]]),contracts_HFC_years[12]], 
                                         'contracts 2020':[sum([contracts_outra_years[13],contracts_hibrido_years[13], contracts_fibra_years[13],contracts_ADSL1_years[13],
                                            contracts_wifi_years[13], contracts_WIMAX_years[13],contracts_VSAT_years[13],
                                            contracts_xDSL_years[13],contracts_SAT_years[13],contracts_FWA_years[13],contracts_FTTH_years[13],contracts_modem_years[13]]),contracts_HFC_years[13]] },
                  index=['Others tecnologies', 'HFC'])
#plot = piegraph_claro_2019_2020.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2019_2020.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2019_2020out = pd.DataFrame({'contracts 2019 (without HFC)':[contracts_outra_years[12],contracts_hibrido_years[12], contracts_fibra_years[12],contracts_ADSL1_years[12],
                                            contracts_wifi_years[12], contracts_WIMAX_years[12], contracts_VSAT_years[12],
                                            contracts_xDSL_years[12],contracts_SAT_years[12],contracts_FWA_years[12],contracts_FTTH_years[12],contracts_modem_years[12]], 
                                         'contracts 2020 (without HFC)':[contracts_outra_years[13],contracts_hibrido_years[13], contracts_fibra_years[13],contracts_ADSL1_years[13],
                                            contracts_wifi_years[13], contracts_WIMAX_years[13], contracts_VSAT_years[13],
                                            contracts_xDSL_years[13],contracts_SAT_years[13],contracts_FWA_years[13],contracts_FTTH_years[13],contracts_modem_years[13]] },
                  index=['Others','Hibrid','Fiber','ADSL1','Wi-Fi','WIMAX','VSAT','xDSL','SAT','FWA','FTTH', 'Modem'])
#plot = piegraph_claro_2019_2020.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2019_2020out.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2021_2022 = pd.DataFrame({'contracts 2021':[sum([contracts_outra_years[14],contracts_hibrido_years[14], contracts_fibra_years[14],contracts_ADSL1_years[14],
                                            contracts_wifi_years[14], contracts_WIMAX_years[14],contracts_VSAT_years[14],
                                            contracts_xDSL_years[14],contracts_SAT_years[14],contracts_FWA_years[14],contracts_FTTH_years[14],contracts_modem_years[14]]),contracts_HFC_years[14]], 
                                         'contracts 2022':[sum([contracts_outra_years[15],contracts_hibrido_years[15], contracts_fibra_years[15],contracts_ADSL1_years[15],
                                            contracts_wifi_years[15], contracts_WIMAX_years[15],contracts_VSAT_years[15],
                                            contracts_xDSL_years[15],contracts_SAT_years[15],contracts_FWA_years[15],contracts_FTTH_years[15],contracts_modem_years[15]]),contracts_HFC_years[15]] },
                  index=['Other tecnologies','HFC'])
#plot = piegraph_claro_2021_2022.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2021_2022.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_claro_2021_2022out = pd.DataFrame({'contracts 2021 (without HFC)':[contracts_outra_years[14],contracts_hibrido_years[14], contracts_fibra_years[14],contracts_ADSL1_years[14],
                                            contracts_wifi_years[14], contracts_WIMAX_years[14],contracts_VSAT_years[14],
                                            contracts_xDSL_years[14],contracts_SAT_years[14],contracts_FWA_years[14],contracts_FTTH_years[14],contracts_modem_years[14]], 
                                         'contracts 2022 (without HFC)':[contracts_outra_years[15],contracts_hibrido_years[15], contracts_fibra_years[15],contracts_ADSL1_years[15],
                                            contracts_wifi_years[15], contracts_WIMAX_years[15],contracts_VSAT_years[15],
                                            contracts_xDSL_years[15],contracts_SAT_years[15],contracts_FWA_years[15],contracts_FTTH_years[15],contracts_modem_years[15]] },
                  index=['Others','Hibrid','Fiber','ADSL1','Wi-Fi','WIMAX','VSAT','xDSL','SAT','FWA','FTTH','Modem'])
#plot = piegraph_claro_2021_2022.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_claro_2021_2022out.plot.pie(subplots=True, figsize=(20, 20))

# %%
time_all=[2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]

claro_all_tecnology1 = pd.DataFrame({'Fiber': contracts_fibra_years,'FTTH':contracts_FTTH_years,'Cable Modem':contracts_modem_years,'HFC':contracts_HFC_years }, index=time_all)

claro_all_tecnology2 = pd.DataFrame({'hibrid':contracts_hibrido_years, 'ADSL1': contracts_ADSL1_years,
                                            'Wi-Fi':contracts_wifi_years, 'WIMAX':contracts_WIMAX_years, 'VSAT':contracts_VSAT_years, 'Others':contracts_outra_years,
                                            'xDSL':contracts_xDSL_years,'SAT':contracts_SAT_years,'FWA':contracts_FWA_years}, index=time_all)
lines = claro_all_tecnology1.plot.line()
lines = claro_all_tecnology2.plot.line()

# %%
claro_all_tecnology2.plot( y=['SAT','VSAT','WIMAX','hibrid'], kind="bar")

# %%
claro_all_tecnology1.plot( y=['Fiber','FTTH','Cable Modem','HFC'], kind="bar")

# %%
##################################################################################################

# %% [markdown]
# Analysis for TIM company in Rio de Janeiro-Brazil

# %%
###################################################################################################

# %%
FTTH_tim=tim_table.loc[tim_table['tecnology']=='FTTH']
FWA_tim=tim_table.loc[tim_table['tecnology']=='FWA']
hibrido_tim=tim_table.loc[tim_table['tecnology']=='Híbrido']
outra_tim=tim_table.loc[tim_table['tecnology']=='Outra']
xDSL_tim=tim_table.loc[tim_table['tecnology']=='xDSL']
fibra_tim=tim_table.loc[tim_table['tecnology']=='Fibra']
WIMAX_tim=tim_table.loc[tim_table['tecnology']=='WIMAX']
HFC_tim=tim_table.loc[tim_table['tecnology']=='HFC']
VSAT_tim=tim_table.loc[tim_table['tecnology']=='VSAT']
SAT_tim=tim_table.loc[tim_table['tecnology']=='SAT']
ETHERNET_tim=tim_table.loc[tim_table['tecnology']=='ETHERNET']
VDSL_tim=tim_table.loc[tim_table['tecnology']=='VDSL']
FR_tim=tim_table.loc[tim_table['tecnology']=='FR']
ATM_tim=tim_table.loc[tim_table['tecnology']=='ATM']

# %%
elementzero=[0]
###############################################################
#   FTTH tecnology TIM
###############################################################
contract_by_year_FTTH_tim=[]
years_FTTH_tim=sorted(list(set(FTTH_tim['year'].tolist())))
for k in sorted(list(set(FTTH_tim['year'].tolist()))):
  tim_year_FTTH=FTTH_tim.loc[FTTH_tim['year']==k]
  contracts_FTTH_tim=[]
  months_FTTH_tim=[]
  for i in list(sorted(set(tim_year_FTTH['month'].tolist()))):
    tim_month_FTTH=tim_year_FTTH.loc[tim_year_FTTH['month']==i]
    tim_N_FTTH=sum(tim_month_FTTH['Number_contracts'].tolist())
    months_FTTH_tim.append(i)
    contracts_FTTH_tim.append(tim_N_FTTH)
  listzero_FTTH_tim=(12-len(months_FTTH_tim))*elementzero
  for i in range(0,len(contracts_FTTH_tim),1):
    listzero_FTTH_tim.insert(months_FTTH_tim[i]-1,contracts_FTTH_tim[i])
  contracts_FTTH_tim=listzero_FTTH_tim
  contract_by_year_FTTH_tim.append(sum(contracts_FTTH_tim))
###########################################################################
listzero_FTTH_years_tim=elementzero*(16-len(years_FTTH_tim))
for i in range(0,len(contract_by_year_FTTH),1):
    listzero_FTTH_years_tim.insert(years_FTTH_tim[i]-2007,contract_by_year_FTTH_tim[i])
contracts_FTTH_years_tim=listzero_FTTH_years_tim
############################################################################
###############################################################
#   FWA tecnology TIM
###############################################################
contract_by_year_FWA_tim=[]
years_FWA_tim=sorted(list(set(FWA_tim['year'].tolist())))
for k in sorted(list(set(FWA_tim['year'].tolist()))):
  tim_year_FWA=FWA_tim.loc[FWA_tim['year']==k]
  contracts_FWA_tim=[]
  months_FWA_tim=[]
  for i in list(sorted(set(tim_year_FWA['month'].tolist()))):
    tim_month_FWA=tim_year_FWA.loc[tim_year_FWA['month']==i]
    tim_N_FWA=sum(tim_month_FWA['Number_contracts'].tolist())
    months_FWA_tim.append(i)
    contracts_FWA_tim.append(tim_N_FWA)
  listzero_FWA_tim=(12-len(months_FWA_tim))*elementzero
  for i in range(0,len(contracts_FWA_tim),1):
    listzero_FWA_tim.insert(months_FWA_tim[i]-1,contracts_FWA_tim[i])
  contracts_FWA_tim=listzero_FWA_tim
  contract_by_year_FWA_tim.append(sum(contracts_FWA_tim))
###########################################################################
listzero_FWA_years_tim=elementzero*(16-len(years_FWA_tim))
for i in range(0,len(contract_by_year_FWA_tim),1):
  listzero_FWA_years_tim.insert(years_FWA_tim[i]-2007, contract_by_year_FWA_tim[i])
contracts_FWA_years_tim=listzero_FWA_years_tim
############################################################################
###############################################################
#   hibrid tecnology TIM
###############################################################
contract_by_year_hibrido_tim=[]
years_hibrido_tim=sorted(list(set(hibrido_tim['year'].tolist())))
for k in sorted(list(set(hibrido_tim['year'].tolist()))):
  tim_year_hibrido=hibrido_tim.loc[hibrido_tim['year']==k]
  contracts_hibrido_tim=[]
  months_hibrido_tim=[]
  for i in list(sorted(set(tim_year_hibrido['month'].tolist()))):
    tim_month_hibrido=tim_year_hibrido.loc[tim_year_hibrido['month']==i]
    tim_N_hibrido=sum(tim_month_hibrido['Number_contracts'].tolist())
    months_hibrido_tim.append(i)
    contracts_hibrido_tim.append(tim_N_hibrido)
  listzero_hibrido_tim=(12-len(months_hibrido_tim))*elementzero
  for i in range(0,len(contracts_hibrido_tim),1):
    listzero_hibrido_tim.insert(months_hibrido_tim[i]-1,contracts_hibrido_tim[i])
  contracts_hibrido_tim=listzero_hibrido_tim
  contract_by_year_hibrido_tim.append(sum(contracts_hibrido_tim))
###########################################################################
listzero_hibrido_years_tim=elementzero*(16-len(years_hibrido_tim))
for i in range(0,len(contract_by_year_hibrido_tim),1):
  listzero_hibrido_years_tim.insert(years_hibrido_tim[i]-2007, contract_by_year_hibrido_tim[i])
contracts_hibrido_years_tim=listzero_hibrido_years_tim
############################################################################
###############################################################
#   other tecnologies TIM
###############################################################
contract_by_year_outra_tim=[]
years_outra_tim=sorted(list(set(outra_tim['year'].tolist())))
for k in sorted(list(set(outra_tim['year'].tolist()))):
  tim_year_outra=outra_tim.loc[outra_tim['year']==k]
  contracts_outra_tim=[]
  months_outra_tim=[]
  for i in list(sorted(set(tim_year_outra['month'].tolist()))):
    tim_month_outra=tim_year_outra.loc[tim_year_outra['month']==i]
    tim_N_outra=sum(tim_month_outra['Number_contracts'].tolist())
    months_outra_tim.append(i)
    contracts_outra_tim.append(tim_N_outra)
  listzero_outra_tim=(12-len(months_outra_tim))*elementzero
  for i in range(0,len(contracts_outra_tim),1):
    listzero_outra_tim.insert(months_outra_tim[i]-1,contracts_outra_tim[i])
  contracts_outra_tim=listzero_outra_tim
  contract_by_year_outra_tim.append(sum(contracts_outra_tim))
###########################################################################
listzero_outra_years_tim=elementzero*(16-len(years_outra_tim))
for i in range(0,len(contract_by_year_outra_tim),1):
  listzero_outra_years_tim.insert(years_outra_tim[i]-2007, contract_by_year_outra_tim[i])
contracts_outra_years_tim=listzero_outra_years_tim
############################################################################
###############################################################
#   SAT tecnology TIM
###############################################################
contract_by_year_SAT_tim=[]
years_SAT_tim=sorted(list(set(SAT_tim['year'].tolist())))
for k in sorted(list(set(SAT_tim['year'].tolist()))):
  tim_year_SAT=SAT_tim.loc[SAT_tim['year']==k]
  contracts_SAT_tim=[]
  months_SAT_tim=[]
  for i in list(sorted(set(tim_year_SAT['month'].tolist()))):
    tim_month_SAT=tim_year_SAT.loc[tim_year_SAT['month']==i]
    tim_N_SAT=sum(tim_month_SAT['Number_contracts'].tolist())
    months_SAT_tim.append(i)
    contracts_SAT_tim.append(tim_N_SAT)
  listzero_SAT_tim=(12-len(months_SAT_tim))*elementzero
  for i in range(0,len(contracts_SAT_tim),1):
    listzero_SAT_tim.insert(months_SAT_tim[i]-1,contracts_SAT_tim[i])
  contracts_SAT_tim=listzero_SAT_tim
  contract_by_year_SAT_tim.append(sum(contracts_SAT_tim))
###########################################################################
listzero_SAT_years_tim=elementzero*(16-len(years_SAT_tim))
for i in range(0,len(contract_by_year_SAT_tim),1):
  listzero_SAT_years_tim.insert(years_SAT_tim[i]-2007, contract_by_year_SAT_tim[i])
contracts_SAT_years_tim=listzero_SAT_years_tim
############################################################################
###############################################################
#   xDSL tecnologies  TIM
###############################################################
contract_by_year_xDSL_tim=[]
years_xDSL_tim=sorted(list(set(xDSL_tim['year'].tolist())))
for k in sorted(list(set(xDSL_tim['year'].tolist()))):
  tim_year_xDSL=xDSL_tim.loc[xDSL_tim['year']==k]
  contracts_xDSL_tim=[]
  months_xDSL_tim=[]
  for i in list(sorted(set(tim_year_xDSL['month'].tolist()))):
    tim_month_xDSL=tim_year_xDSL.loc[tim_year_xDSL['month']==i]
    tim_N_xDSL=sum(tim_month_xDSL['Number_contracts'].tolist())
    months_xDSL_tim.append(i)
    contracts_xDSL_tim.append(tim_N_xDSL)
  listzero_xDSL_tim=(12-len(months_xDSL_tim))*elementzero
  for i in range(0,len(contracts_xDSL_tim),1):
    listzero_xDSL_tim.insert(months_xDSL_tim[i]-1,contracts_xDSL_tim[i])
  contracts_xDSL_tim=listzero_xDSL_tim
  contract_by_year_xDSL_tim.append(sum(contracts_xDSL_tim))
###########################################################################
listzero_xDSL_years_tim=elementzero*(16-len(years_xDSL_tim))
for i in range(0,len(contract_by_year_xDSL_tim),1):
  listzero_xDSL_years_tim.insert(years_xDSL_tim[i]-2007, contract_by_year_xDSL_tim[i])
contracts_xDSL_years_tim=listzero_xDSL_years_tim
############################################################################
###############################################################
#   ETHERNET tecnology TIM
###############################################################
contract_by_year_ETHERNET_tim=[]
years_ETHERNET_tim=sorted(list(set(ETHERNET_tim['year'].tolist())))
for k in sorted(list(set(ETHERNET_tim['year'].tolist()))):
  tim_year_ETHERNET=ETHERNET_tim.loc[ETHERNET_tim['year']==k]
  contracts_ETHERNET_tim=[]
  months_ETHERNET_tim=[]
  for i in list(sorted(set(tim_year_ETHERNET['month'].tolist()))):
    tim_month_ETHERNET=tim_year_ETHERNET.loc[tim_year_ETHERNET['month']==i]
    tim_N_ETHERNET=sum(tim_month_ETHERNET['Number_contracts'].tolist())
    months_ETHERNET_tim.append(i)
    contracts_ETHERNET_tim.append(tim_N_ETHERNET)
  listzero_ETHERNET_tim=(12-len(months_ETHERNET_tim))*elementzero
  for i in range(0,len(contracts_ETHERNET_tim),1):
    listzero_ETHERNET_tim.insert(months_ETHERNET_tim[i]-1,contracts_ETHERNET_tim[i])
  contracts_ETHERNET_tim=listzero_ETHERNET_tim
  contract_by_year_ETHERNET_tim.append(sum(contracts_ETHERNET_tim))
###########################################################################
listzero_ETHERNET_years_tim=elementzero*(16-len(years_ETHERNET_tim))
for i in range(0,len(contract_by_year_ETHERNET_tim),1):
  listzero_ETHERNET_years_tim.insert(years_ETHERNET_tim[i]-2007, contract_by_year_ETHERNET_tim[i])
contracts_ETHERNET_years_tim=listzero_ETHERNET_years_tim
############################################################################
###############################################################
#   Fiber tecnology TIM
###############################################################
contract_by_year_fibra_tim=[]
years_fibra_tim=sorted(list(set(fibra_tim['year'].tolist())))
for k in sorted(list(set(fibra_tim['year'].tolist()))):
  tim_year_fibra=fibra_tim.loc[fibra_tim['year']==k]
  contracts_fibra_tim=[]
  months_fibra_tim=[]
  for i in list(sorted(set(tim_year_fibra['month'].tolist()))):
    tim_month_fibra=tim_year_fibra.loc[tim_year_fibra['month']==i]
    tim_N_fibra=sum(tim_month_fibra['Number_contracts'].tolist())
    months_fibra_tim.append(i)
    contracts_fibra_tim.append(tim_N_fibra)
  listzero_fibra_tim=(12-len(months_fibra_tim))*elementzero
  for i in range(0,len(contracts_fibra_tim),1):
    listzero_fibra_tim.insert(months_fibra_tim[i]-1,contracts_fibra_tim[i])
  contracts_fibra_tim=listzero_fibra_tim
  contract_by_year_fibra_tim.append(sum(contracts_fibra_tim))
###########################################################################
listzero_fibra_years_tim=elementzero*(16-len(years_fibra_tim))
for i in range(0,len(contract_by_year_fibra_tim),1):
  listzero_fibra_years_tim.insert(years_fibra_tim[i]-2007, contract_by_year_fibra_tim[i])
contracts_fibra_years_tim=listzero_fibra_years_tim
############################################################################
###############################################################
#    ATM tecnology TIM
###############################################################
contract_by_year_ATM_tim=[]
years_ATM_tim=sorted(list(set(ATM_tim['year'].tolist())))
for k in sorted(list(set(ATM_tim['year'].tolist()))):
  tim_year_ATM=ATM_tim.loc[ATM_tim['year']==k]
  contracts_ATM_tim=[]
  months_ATM_tim=[]
  for i in list(sorted(set(tim_year_ATM['month'].tolist()))):
    tim_month_ATM=tim_year_ATM.loc[tim_year_ATM['month']==i]
    tim_N_ATM=sum(tim_month_ATM['Number_contracts'].tolist())
    months_ATM_tim.append(i)
    contracts_ATM_tim.append(tim_N_ATM)
  listzero_ATM_tim=(12-len(months_ATM_tim))*elementzero
  for i in range(0,len(contracts_ATM_tim),1):
    listzero_ATM_tim.insert(months_ATM_tim[i]-1,contracts_ATM_tim[i])
  contracts_ATM_tim=listzero_ATM_tim
  contract_by_year_ATM_tim.append(sum(contracts_ATM_tim))
###########################################################################
listzero_ATM_years_tim=elementzero*(16-len(years_ATM_tim))
for i in range(0,len(contract_by_year_ATM_tim),1):
  listzero_ATM_years_tim.insert(years_ATM_tim[i]-2007, contract_by_year_ATM_tim[i])
contracts_ATM_years_tim=listzero_ATM_years_tim
############################################################################
###############################################################
#    HFC tecnology TIM
###############################################################
contract_by_year_HFC_tim=[]
years_HFC_tim=sorted(list(set(HFC_tim['year'].tolist())))
for k in sorted(list(set(HFC_tim['year'].tolist()))):
  tim_year_HFC=HFC_tim.loc[HFC_tim['year']==k]
  contracts_HFC_tim=[]
  months_HFC_tim=[]
  for i in list(sorted(set(tim_year_HFC['month'].tolist()))):
    tim_month_HFC=tim_year_HFC.loc[tim_year_HFC['month']==i]
    tim_N_HFC=sum(tim_month_HFC['Number_contracts'].tolist())
    months_HFC_tim.append(i)
    contracts_HFC_tim.append(tim_N_HFC)
  listzero_HFC_tim=(12-len(months_HFC_tim))*elementzero
  for i in range(0,len(contracts_HFC_tim),1):
    listzero_HFC_tim.insert(months_HFC_tim[i]-1,contracts_HFC_tim[i])
  contracts_HFC_tim=listzero_HFC_tim
  contract_by_year_HFC_tim.append(sum(contracts_HFC_tim))
###########################################################################
listzero_HFC_years_tim=elementzero*(16-len(years_HFC_tim))
for i in range(0,len(contract_by_year_HFC_tim),1):
  listzero_HFC_years_tim.insert(years_HFC_tim[i]-2007, contract_by_year_HFC_tim[i])
contracts_HFC_years_tim=listzero_HFC_years_tim
############################################################################
###############################################################
#    VSAT tecnology  TIM
###############################################################
contract_by_year_VSAT_tim=[]
years_VSAT_tim=sorted(list(set(VSAT_tim['year'].tolist())))
for k in sorted(list(set(VSAT_tim['year'].tolist()))):
  tim_year_VSAT=VSAT_tim.loc[VSAT_tim['year']==k]
  contracts_VSAT_tim=[]
  months_VSAT_tim=[]
  for i in list(sorted(set(tim_year_VSAT['month'].tolist()))):
    tim_month_VSAT=tim_year_VSAT.loc[tim_year_VSAT['month']==i]
    tim_N_VSAT=sum(tim_month_VSAT['Number_contracts'].tolist())
    months_VSAT_tim.append(i)
    contracts_VSAT_tim.append(tim_N_VSAT)
  listzero_VSAT_tim=(12-len(months_VSAT_tim))*elementzero
  for i in range(0,len(contracts_VSAT_tim),1):
    listzero_VSAT_tim.insert(months_VSAT_tim[i]-1,contracts_VSAT_tim[i])
  contracts_VSAT_tim=listzero_VSAT_tim
  contract_by_year_VSAT_tim.append(sum(contracts_VSAT_tim))
###########################################################################
listzero_VSAT_years_tim=elementzero*(16-len(years_VSAT_tim))
for i in range(0,len(contract_by_year_VSAT_tim),1):
  listzero_VSAT_years_tim.insert(years_VSAT_tim[i]-2007, contract_by_year_VSAT_tim[i])
contracts_VSAT_years_tim=listzero_VSAT_years_tim
############################################################################
###############################################################
#    WIMAX tecnology TIM
###############################################################
contract_by_year_WIMAX_tim=[]
years_WIMAX_tim=sorted(list(set(WIMAX_tim['year'].tolist())))
for k in sorted(list(set(WIMAX_tim['year'].tolist()))):
  tim_year_WIMAX=WIMAX_tim.loc[WIMAX_tim['year']==k]
  contracts_WIMAX_tim=[]
  months_WIMAX_tim=[]
  for i in list(sorted(set(tim_year_WIMAX['month'].tolist()))):
    tim_month_WIMAX=tim_year_WIMAX.loc[tim_year_WIMAX['month']==i]
    tim_N_WIMAX=sum(tim_month_WIMAX['Number_contracts'].tolist())
    months_WIMAX_tim.append(i)
    contracts_WIMAX_tim.append(tim_N_WIMAX)
  listzero_WIMAX_tim=(12-len(months_WIMAX_tim))*elementzero
  for i in range(0,len(contracts_WIMAX_tim),1):
    listzero_WIMAX_tim.insert(months_WIMAX_tim[i]-1,contracts_WIMAX_tim[i])
  contracts_WIMAX_tim=listzero_WIMAX_tim
  contract_by_year_WIMAX_tim.append(sum(contracts_WIMAX_tim))
###########################################################################
listzero_WIMAX_years_tim=elementzero*(16-len(years_WIMAX_tim))
for i in range(0,len(contract_by_year_WIMAX_tim),1):
  listzero_WIMAX_years_tim.insert(years_WIMAX_tim[i]-2007, contract_by_year_WIMAX_tim[i])
contracts_WIMAX_years_tim=listzero_WIMAX_years_tim
############################################################################
###############################################################
#    VDSL tecnology  TIM
###############################################################
contract_by_year_VDSL_tim=[]
years_VDSL_tim=sorted(list(set(VDSL_tim['year'].tolist())))
for k in sorted(list(set(VDSL_tim['year'].tolist()))):
  tim_year_VDSL=VDSL_tim.loc[VDSL_tim['year']==k]
  contracts_VDSL_tim=[]
  months_VDSL_tim=[]
  for i in list(sorted(set(tim_year_VDSL['month'].tolist()))):
    tim_month_VDSL=tim_year_VDSL.loc[tim_year_VDSL['month']==i]
    tim_N_VDSL=sum(tim_month_VDSL['Number_contracts'].tolist())
    months_VDSL_tim.append(i)
    contracts_VDSL_tim.append(tim_N_VDSL)
  listzero_VDSL_tim=(12-len(months_VDSL_tim))*elementzero
  for i in range(0,len(contracts_VDSL_tim),1):
    listzero_VDSL_tim.insert(months_VDSL_tim[i]-1,contracts_VDSL_tim[i])
  contracts_VDSL_tim=listzero_VDSL_tim
  contract_by_year_VDSL_tim.append(sum(contracts_VDSL_tim))
###########################################################################
listzero_VDSL_years_tim=elementzero*(16-len(years_VDSL_tim))
for i in range(0,len(contract_by_year_VDSL_tim),1):
  listzero_VDSL_years_tim.insert(years_VDSL_tim[i]-2007, contract_by_year_VDSL_tim[i])
contracts_VDSL_years_tim=listzero_VDSL_years_tim
############################################################################
###############################################################
#    FR tecnology TIM
###############################################################
contract_by_year_FR_tim=[]
years_FR_tim=sorted(list(set(FR_tim['year'].tolist())))
for k in sorted(list(set(FR_tim['year'].tolist()))):
  tim_year_FR=FR_tim.loc[FR_tim['year']==k]
  contracts_FR_tim=[]
  months_FR_tim=[]
  for i in list(sorted(set(tim_year_FR['month'].tolist()))):
    tim_month_FR=tim_year_FR.loc[tim_year_FR['month']==i]
    tim_N_FR=sum(tim_month_FR['Number_contracts'].tolist())
    months_FR_tim.append(i)
    contracts_FR_tim.append(tim_N_FR)
  listzero_FR_tim=(12-len(months_FR_tim))*elementzero
  for i in range(0,len(contracts_FR_tim),1):
    listzero_FR_tim.insert(months_FR_tim[i]-1,contracts_FR_tim[i])
  contracts_FR_tim=listzero_FR_tim
  contract_by_year_FR_tim.append(sum(contracts_FR_tim))
###########################################################################
listzero_FR_years_tim=elementzero*(16-len(years_FR_tim))
for i in range(0,len(contract_by_year_FR_tim),1):
  listzero_FR_years_tim.insert(years_FR_tim[i]-2007, contract_by_year_FR_tim[i])
contracts_FR_years_tim=listzero_FR_years_tim
############################################################################

# %%
time_all=[2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]

piegraph_tim_2007_2008 = pd.DataFrame({'TIM contracts 2007 ': [contracts_outra_years_tim[0],contracts_hibrido_years_tim[0], contracts_fibra_years_tim[0],
                                             contracts_WIMAX_years_tim[0], contracts_HFC_years_tim[0],contracts_VSAT_years_tim[0],
                                            contracts_xDSL_years_tim[0],contracts_SAT_years_tim[0],contracts_FWA_years_tim[0],
                                            contracts_FTTH_years_tim[0], contracts_ETHERNET_years_tim[0], contracts_ATM_years_tim[0],
                                             contracts_VDSL_years_tim[0], contracts_FR_years_tim[0] ],
                               'TIM contracts 2008':[contracts_outra_years_tim[1],contracts_hibrido_years_tim[1], contracts_fibra_years_tim[1],
                                             contracts_WIMAX_years_tim[1], contracts_HFC_years_tim[1],contracts_VSAT_years_tim[1],
                                            contracts_xDSL_years_tim[1],contracts_SAT_years_tim[1],contracts_FWA_years_tim[1],
                                            contracts_FTTH_years_tim[1], contracts_ETHERNET_years_tim[1], contracts_ATM_years_tim[1],
                                             contracts_VDSL_years_tim[1], contracts_FR_years_tim[1]]},
                  index=['Other', 'Hibrid','Fiber','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH','ETHERNET','ATM','VDSL','FR'])
#plot = piegraph_claro_2007_2008.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_tim_2007_2008.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_tim_2009_2010 = pd.DataFrame({'TIM contracts 2009': [contracts_outra_years_tim[2],contracts_hibrido_years_tim[2], contracts_fibra_years_tim[2],
                                             contracts_WIMAX_years_tim[2], contracts_HFC_years_tim[2],contracts_VSAT_years_tim[2],
                                            contracts_xDSL_years_tim[2],contracts_SAT_years_tim[2],contracts_FWA_years_tim[2],
                                            contracts_FTTH_years_tim[2], contracts_ETHERNET_years_tim[2], contracts_ATM_years_tim[2],
                                             contracts_VDSL_years_tim[2], contracts_FR_years_tim[2] ],
                               'TIM contracts 2010':[contracts_outra_years_tim[3],contracts_hibrido_years_tim[3], contracts_fibra_years_tim[3],
                                             contracts_WIMAX_years_tim[3], contracts_HFC_years_tim[3],contracts_VSAT_years_tim[3],
                                            contracts_xDSL_years_tim[3],contracts_SAT_years_tim[3],contracts_FWA_years_tim[3],
                                            contracts_FTTH_years_tim[3], contracts_ETHERNET_years_tim[3], contracts_ATM_years_tim[3],
                                             contracts_VDSL_years_tim[3], contracts_FR_years_tim[3]]},
                  index=['Other', 'Hibrid','Fiber','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH','ETHERNET','ATM','VDSL','FR'])
#plot = piegraph_claro_2007_2008.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_tim_2009_2010.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_tim_2011_2012 = pd.DataFrame({'TIM contracts 2011': [contracts_outra_years_tim[4],contracts_hibrido_years_tim[4], contracts_fibra_years_tim[4],
                                             contracts_WIMAX_years_tim[4], contracts_HFC_years_tim[4],contracts_VSAT_years_tim[4],
                                            contracts_xDSL_years_tim[4],contracts_SAT_years_tim[4],contracts_FWA_years_tim[4],
                                            contracts_FTTH_years_tim[4], contracts_ETHERNET_years_tim[4], contracts_ATM_years_tim[4],
                                             contracts_VDSL_years_tim[4], contracts_FR_years_tim[4] ],
                               'TIM contracts 2012':[contracts_outra_years_tim[5],contracts_hibrido_years_tim[5], contracts_fibra_years_tim[5],
                                             contracts_WIMAX_years_tim[5], contracts_HFC_years_tim[5],contracts_VSAT_years_tim[5],
                                            contracts_xDSL_years_tim[5],contracts_SAT_years_tim[5],contracts_FWA_years_tim[5],
                                            contracts_FTTH_years_tim[5], contracts_ETHERNET_years_tim[5], contracts_ATM_years_tim[5],
                                             contracts_VDSL_years_tim[5], contracts_FR_years_tim[5]]},
                  index=['Other', 'Hibrid','Fiber','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH','ETHERNET','ATM','VDSL','FR'])
#plot = piegraph_claro_2007_2008.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_tim_2011_2012.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_tim_2013_2014 = pd.DataFrame({'TIM contracts 2013': [contracts_outra_years_tim[6],contracts_hibrido_years_tim[6], contracts_fibra_years_tim[6],
                                             contracts_WIMAX_years_tim[6], contracts_HFC_years_tim[6],contracts_VSAT_years_tim[6],
                                            contracts_xDSL_years_tim[6],contracts_SAT_years_tim[6],contracts_FWA_years_tim[6],
                                            contracts_FTTH_years_tim[6], contracts_ETHERNET_years_tim[6], contracts_ATM_years_tim[6],
                                             contracts_VDSL_years_tim[6], contracts_FR_years_tim[6]],
                               'TIM contracts 2014':[contracts_outra_years_tim[7],contracts_hibrido_years_tim[7], contracts_fibra_years_tim[7],
                                             contracts_WIMAX_years_tim[7], contracts_HFC_years_tim[7],contracts_VSAT_years_tim[7],
                                            contracts_xDSL_years_tim[7],contracts_SAT_years_tim[7],contracts_FWA_years_tim[7],
                                            contracts_FTTH_years_tim[7], contracts_ETHERNET_years_tim[7], contracts_ATM_years_tim[7],
                                             contracts_VDSL_years_tim[7], contracts_FR_years_tim[7]]},
                  index=['Other', 'Hibrid','Fiber','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH','ETHERNET','ATM','VDSL','FR'])
#plot = piegraph_claro_2007_2008.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_tim_2013_2014.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_tim_2015_2016 = pd.DataFrame({'TIM contracts 2015': [sum([contracts_outra_years_tim[8],contracts_hibrido_years_tim[8], contracts_fibra_years_tim[8],
                                             contracts_WIMAX_years_tim[8], contracts_HFC_years_tim[8],contracts_VSAT_years_tim[8],
                                            contracts_SAT_years_tim[8],contracts_FWA_years_tim[8],
                                            contracts_FTTH_years_tim[8], contracts_ETHERNET_years_tim[8], contracts_ATM_years_tim[8],
                                             contracts_VDSL_years_tim[8], contracts_FR_years_tim[8]]), contracts_xDSL_years_tim[8]],
                               'TIM contracts 2016':[sum([contracts_outra_years_tim[9],contracts_hibrido_years_tim[9], contracts_fibra_years_tim[9],
                                             contracts_WIMAX_years_tim[9], contracts_HFC_years_tim[9],contracts_VSAT_years_tim[9],
                                            contracts_SAT_years_tim[9],contracts_FWA_years_tim[9],
                                            contracts_FTTH_years_tim[9], contracts_ETHERNET_years_tim[9], contracts_ATM_years_tim[9],
                                             contracts_VDSL_years_tim[9], contracts_FR_years_tim[9]]),contracts_xDSL_years_tim[9]]},
                  index=['Other tecnologies','xDSL'])


plot = piegraph_tim_2015_2016.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_tim_2015_2016out = pd.DataFrame({'TIM contracts 2015 (without xDSL)': [contracts_outra_years_tim[8],contracts_hibrido_years_tim[8], contracts_fibra_years_tim[8],
                                             contracts_WIMAX_years_tim[8], contracts_HFC_years_tim[8],contracts_VSAT_years_tim[8],
                                            contracts_SAT_years_tim[8],contracts_FWA_years_tim[8],
                                            contracts_FTTH_years_tim[8], contracts_ETHERNET_years_tim[8], contracts_ATM_years_tim[8],
                                             contracts_VDSL_years_tim[8], contracts_FR_years_tim[8]],
                               'TIM contracts 2016 (without xDSL)':[contracts_outra_years_tim[9],contracts_hibrido_years_tim[9], contracts_fibra_years_tim[9],
                                             contracts_WIMAX_years_tim[9], contracts_HFC_years_tim[9],contracts_VSAT_years_tim[9],
                                            contracts_SAT_years_tim[9],contracts_FWA_years_tim[9],
                                            contracts_FTTH_years_tim[9], contracts_ETHERNET_years_tim[9], contracts_ATM_years_tim[9],
                                             contracts_VDSL_years_tim[9], contracts_FR_years_tim[9]]},
                  index=['Other', 'Hibrid','Fiber','WIMAX','HFC','VSAT','SAT','FWA','FTTH','ETHERNET','ATM','VDSL','FR'])
#plot = piegraph_claro_2007_2008.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_tim_2015_2016out.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_tim_2017_2018 = pd.DataFrame({'TIM contracts 2017': [sum([contracts_outra_years_tim[10],contracts_hibrido_years_tim[10], contracts_fibra_years_tim[10],
                                             contracts_WIMAX_years_tim[10], contracts_HFC_years_tim[10],contracts_VSAT_years_tim[10],
                                            contracts_SAT_years_tim[10],contracts_FWA_years_tim[10],
                                            contracts_FTTH_years_tim[10], contracts_ETHERNET_years_tim[10], contracts_ATM_years_tim[10],
                                             contracts_VDSL_years_tim[10], contracts_FR_years_tim[10]]),contracts_xDSL_years_tim[10]],
                               'TIM contracts 2018':[sum([contracts_outra_years_tim[11],contracts_hibrido_years_tim[11], contracts_fibra_years_tim[11],
                                             contracts_WIMAX_years_tim[11], contracts_HFC_years_tim[11],contracts_VSAT_years_tim[11],
                                            contracts_SAT_years_tim[11],contracts_FWA_years_tim[11],
                                            contracts_FTTH_years_tim[11], contracts_ETHERNET_years_tim[11], contracts_ATM_years_tim[11],
                                             contracts_VDSL_years_tim[11], contracts_FR_years_tim[11]]), contracts_xDSL_years_tim[11]]},
                  index=['Other tecnologies', 'xDSL'])
#plot = piegraph_claro_2007_2008.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_tim_2017_2018.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_tim_2017_2018out = pd.DataFrame({'TIM contracts 2017(without xDSL)': [contracts_outra_years_tim[10],contracts_hibrido_years_tim[10], contracts_fibra_years_tim[10],
                                             contracts_WIMAX_years_tim[10], contracts_HFC_years_tim[10],contracts_VSAT_years_tim[10],
                                            contracts_SAT_years_tim[10],contracts_FWA_years_tim[10],
                                            contracts_FTTH_years_tim[10], contracts_ETHERNET_years_tim[10], contracts_ATM_years_tim[10],
                                             contracts_VDSL_years_tim[10], contracts_FR_years_tim[10]],
                               'TIM contracts 2018(without xDSL)':[contracts_outra_years_tim[11],contracts_hibrido_years_tim[11], contracts_fibra_years_tim[11],
                                             contracts_WIMAX_years_tim[11], contracts_HFC_years_tim[11],contracts_VSAT_years_tim[11],
                                            contracts_SAT_years_tim[11],contracts_FWA_years_tim[11],
                                            contracts_FTTH_years_tim[11], contracts_ETHERNET_years_tim[11], contracts_ATM_years_tim[11],
                                             contracts_VDSL_years_tim[11], contracts_FR_years_tim[11]]},
                  index=['Other', 'Hibrid','Fiber','WIMAX','HFC','VSAT','SAT','FWA','FTTH','ETHERNET','ATM','VDSL','FR'])

plot = piegraph_tim_2017_2018out.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_tim_2019_2020 = pd.DataFrame({'TIM contracts 2019': [contracts_outra_years_tim[12],contracts_hibrido_years_tim[12], contracts_fibra_years_tim[12],
                                             contracts_WIMAX_years_tim[12], contracts_HFC_years_tim[12],contracts_VSAT_years_tim[12],
                                            contracts_xDSL_years_tim[12],contracts_SAT_years_tim[12],contracts_FWA_years_tim[12],
                                            contracts_FTTH_years_tim[12], contracts_ETHERNET_years_tim[12], contracts_ATM_years_tim[12],
                                             contracts_VDSL_years_tim[12], contracts_FR_years_tim[12]],
                               'TIM contracts 2020':[contracts_outra_years_tim[13],contracts_hibrido_years_tim[13], contracts_fibra_years_tim[13],
                                             contracts_WIMAX_years_tim[13], contracts_HFC_years_tim[13],contracts_VSAT_years_tim[13],
                                            contracts_xDSL_years_tim[13],contracts_SAT_years_tim[13],contracts_FWA_years_tim[13],
                                            contracts_FTTH_years_tim[13], contracts_ETHERNET_years_tim[13], contracts_ATM_years_tim[13],
                                             contracts_VDSL_years_tim[13], contracts_FR_years_tim[13]]},
                  index=['Other', 'Hibrid','Fiber','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH','ETHERNET','ATM','VDSL','FR'])
#plot = piegraph_claro_2007_2008.plot.pie(y='contracts 2007', figsize=(10, 10))

plot = piegraph_tim_2019_2020.plot.pie(subplots=True, figsize=(20, 20))

# %%
piegraph_tim_2021_2022 = pd.DataFrame({'TIM contracts 2021': [contracts_outra_years_tim[14],contracts_hibrido_years_tim[14], contracts_fibra_years_tim[14],
                                             contracts_WIMAX_years_tim[14], contracts_HFC_years_tim[14],contracts_VSAT_years_tim[14],
                                            contracts_xDSL_years_tim[14],contracts_SAT_years_tim[14],contracts_FWA_years_tim[14],
                                            contracts_FTTH_years_tim[14], contracts_ETHERNET_years_tim[14], contracts_ATM_years_tim[14],
                                             contracts_VDSL_years_tim[14], contracts_FR_years_tim[14]],
                               'TIM contracts 2022':[contracts_outra_years_tim[15],contracts_hibrido_years_tim[15], contracts_fibra_years_tim[15],
                                             contracts_WIMAX_years_tim[15], contracts_HFC_years_tim[15],contracts_VSAT_years_tim[15],
                                            contracts_xDSL_years_tim[15],contracts_SAT_years_tim[15],contracts_FWA_years_tim[15],
                                            contracts_FTTH_years_tim[15], contracts_ETHERNET_years_tim[15], contracts_ATM_years_tim[15],
                                             contracts_VDSL_years_tim[15], contracts_FR_years_tim[15]]},
                  index=['Other', 'Hibrid','Fiber','WIMAX','HFC','VSAT','xDSL','SAT','FWA','FTTH','ETHERNET','ATM','VDSL','FR'])

plot = piegraph_tim_2021_2022.plot.pie(subplots=True, figsize=(20, 20))

# %%
time_all=[2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]

tim_all_tecnology1 = pd.DataFrame({'Fiber': contracts_fibra_years_tim,'FTTH':contracts_FTTH_years_tim,'xDSL':contracts_xDSL_years_tim,'VDSL':contracts_VDSL_years_tim }, index=time_all)

tim_all_tecnology2 = pd.DataFrame({'Hibrid':contracts_hibrido_years_tim, 'ATM':contracts_ATM_years_tim, 'WIMAX':contracts_WIMAX_years_tim, 'VSAT':contracts_VSAT_years_tim,
                                   'Others':contracts_outra_years_tim, 'FR':contracts_FR_years_tim,'SAT':contracts_SAT_years_tim,
                                   'FWA':contracts_FWA_years_tim, 'HFC':contracts_HFC_years_tim, 'ETHERNET': contracts_ETHERNET_years_tim }, index=time_all)
lines = tim_all_tecnology1.plot.line()
lines = tim_all_tecnology2.plot.line()

# %%
tim_all_tecnology1.plot( y=['Fiber','FTTH','xDSL','VDSL'], kind="bar")

# %%
tim_all_tecnology2.plot( y=['Hibrid','ATM','WIMAX','VSAT','Others','FR','SAT','FWA','HFC','ETHERNET'], kind="bar")

# %% [markdown]
# Sum of contracts per year. (TIM company)

# %%
all_year_tim=[]
for y in range(0,len(time_all),1):
  tim_y = sum([contracts_outra_years_tim[y],contracts_hibrido_years_tim[y], contracts_fibra_years_tim[y],
                                             contracts_WIMAX_years_tim[y], contracts_HFC_years_tim[y],contracts_VSAT_years_tim[y],
                                            contracts_xDSL_years_tim[y],contracts_SAT_years_tim[y],contracts_FWA_years_tim[y],
                                            contracts_FTTH_years_tim[y], contracts_ETHERNET_years_tim[y], contracts_ATM_years_tim[y],
                                             contracts_VDSL_years_tim[y], contracts_FR_years_tim[y]])
  all_year_tim.append(tim_y)
print(all_year_tim)
# Out:
# [3174, 3527, 4059, 5014, 26882, 61269, 229177, 515796, 950538, 1543245, 1907395, 2293515, 2483540, 2300145, 2026378, 332019]

# %%
all_year_claro=[]
for y in range(0,len(time_all),1):
  claro_y = sum([contracts_outra_years[y],contracts_hibrido_years[y], contracts_fibra_years[y],contracts_ADSL1_years[y],
                                            contracts_wifi_years[y], contracts_WIMAX_years[y], contracts_HFC_years[y],contracts_VSAT_years[y],
                                            contracts_xDSL_years[y],contracts_SAT_years[y],contracts_FWA_years[y],contracts_FTTH_years[y],contracts_modem_years[y]])
  all_year_claro.append(claro_y)
print(all_year_claro)
# Out:
# [696036, 971086, 1240031, 1505820, 5833252, 7483198, 6922772, 6514612, 11579691, 12409310, 12538051, 12893137, 13078587, 13319566, 13740179, 2317496]

# %%
graphic_comper = pd.DataFrame({'TIM Contracts in RJ-BR': all_year_tim ,'Claro Contracts in RJ-BR': all_year_claro }, index=time_all)
lines = graphic_comper.plot.line()

# %%
 graphic_comper.plot( y=['TIM Contracts in RJ-BR', 'Claro Contracts in RJ-BR'], kind="bar")
